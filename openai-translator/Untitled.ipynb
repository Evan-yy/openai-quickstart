# %%
# !python ai_translator/main.py --model_type OpenAIModel --file_format markdown --book tests/test.pdf --openai_model gpt-3.5-turbo --target_language "日文"
# Out:
# 2024-07-17 11:38:41.333 | DEBUG    | translator.pdf_parser:parse_pdf:46 - [raw_text]
#  Test Data
# This dataset contains two test samples provided by ChatGPT, an AI language model by OpenAI.
# These samples include a markdown table and an English text passage, which can be used to test an
# English-to-Chinese translation software supporting both text and table formats.
# Text testing
# The quick brown fox jumps over the lazy dog. This pangram contains every letter of the English
# alphabet at least once. Pangrams are often used to test fonts, keyboards, and other text-related
# tools. In addition to English, there are pangrams in many other languages. Some pangrams are more
# difficult to construct due to the unique characteristics of the language.
# Table Testing
# 2024-07-17 11:38:41.341 | DEBUG    | translator.pdf_parser:parse_pdf:54 - [table]
# [Fruit, Color, Price (USD)] [Apple, Red, 1.20] [Banana, Yellow, 0.50] [Orange, Orange, 0.80] [Strawberry, Red, 2.50] [Blueberry, Blue, 3.00] [Kiwi, Green, 1.00] [Mango, Orange, 1.50] [Grape, Purple, 2.00]
# 2024-07-17 11:38:47.926 | INFO     | translator.writer:_save_translated_book_markdown:83 - pdf_file_path: tests/test.pdf
# --- Logging error in Loguru Handler #1 ---
# Record was: {'elapsed': datetime.timedelta(seconds=3, microseconds=740038), 'exception': None, 'extra': {}, 'file': (name='pdf_translator.py', path='D:\\Evan\\ITA\\Training\\open-AI\\HW\\openai-quickstart\\openai-translator\\ai_translator\\translator\\pdf_translator.py'), 'function': 'translate_pdf', 'level': (name='DEBUG', no=10, icon='\U0001f41e'), 'line': 19, 'message': '\u7ffb\u8bd1\u4e3a\u65e5\u6587\uff1aTest Data\nThis dataset contains two test samples provided by ChatGPT, an AI language model by OpenAI.\nThese samples include a markdown table and an English text passage, which can be used to test an\nEnglish-to-Chinese translation software supporting both text and table formats.\nText testing\nThe quick brown fox jumps over the lazy dog. This pangram contains every letter of the English\nalphabet at least once. Pangrams are often used to test fonts, keyboards, and other text-related\ntools. In addition to English, there are pangrams in many other languages. Some pangrams are more\ndifficult to construct due to the unique characteristics of the language.\nTable Testing', 'module': 'pdf_translator', 'name': 'translator.pdf_translator', 'process': (id=38860, name='MainProcess'), 'thread': (id=51360, name='MainThread'), 'time': datetime(2024, 7, 17, 11, 38, 41, 367696, tzinfo=datetime.timezone(datetime.timedelta(seconds=28800), 'China Standard Time'))}
# Traceback (most recent call last):
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_handler.py", line 206, in emit
#     self._sink.write(str_record)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_simple_sinks.py", line 16, in write
#     self._stream.write(message)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 140-145: character maps to <undefined>
# --- End of logging error ---
# --- Logging error in Loguru Handler #1 ---
# Record was: {'elapsed': datetime.timedelta(seconds=8, microseconds=139473), 'exception': None, 'extra': {}, 'file': (name='pdf_translator.py', path='D:\\Evan\\ITA\\Training\\open-AI\\HW\\openai-quickstart\\openai-translator\\ai_translator\\translator\\pdf_translator.py'), 'function': 'translate_pdf', 'level': (name='INFO', no=20, icon='\u2139\ufe0f'), 'line': 21, 'message': '\u30c6\u30b9\u30c8\u30c7\u30fc\u30bf\n\u3053\u306e\u30c7\u30fc\u30bf\u30bb\u30c3\u30c8\u306b\u306f\u3001OpenAI\u306eAI\u8a00\u8a9e\u30e2\u30c7\u30eb\u3067\u3042\u308bChatGPT\u304c\u63d0\u4f9b\u3059\u308b2\u3064\u306e\u30c6\u30b9\u30c8\u30b5\u30f3\u30d7\u30eb\u304c\u542b\u307e\u308c\u3066\u3044\u307e\u3059\u3002\n\u3053\u308c\u3089\u306e\u30b5\u30f3\u30d7\u30eb\u306b\u306f\u3001\u30de\u30fc\u30af\u30c0\u30a6\u30f3\u30c6\u30fc\u30d6\u30eb\u3068\u82f1\u6587\u30c6\u30ad\u30b9\u30c8\u304c\u542b\u307e\u308c\u3066\u304a\u308a\u3001\u30c6\u30ad\u30b9\u30c8\u3068\u30c6\u30fc\u30d6\u30eb\u306e\u4e21\u65b9\u306e\u5f62\u5f0f\u3092\u30b5\u30dd\u30fc\u30c8\u3059\u308b\u82f1\u4e2d\u7ffb\u8a33\u30bd\u30d5\u30c8\u30a6\u30a7\u30a2\u306e\u30c6\u30b9\u30c8\u306b\u4f7f\u7528\u3059\u308b\u3053\u3068\u304c\u3067\u304d\u307e\u3059\u3002\n\u30c6\u30ad\u30b9\u30c8\u306e\u30c6\u30b9\u30c8\n\u901f\u3044\u8336\u8272\u306e\u30ad\u30c4\u30cd\u304c\u306e\u308d\u307e\u306a\u72ac\u3092\u98db\u3073\u8d8a\u3048\u307e\u3059\u3002\u3053\u306e\u30d1\u30f3\u30b0\u30e9\u30e0\u306b\u306f\u3001\u82f1\u8a9e\u306e\u30a2\u30eb\u30d5\u30a1\u30d9\u30c3\u30c8\u306e\u3059\u3079\u3066\u306e\u6587\u5b57\u304c\u5c11\u306a\u304f\u3068\u30821\u56de\u542b\u307e\u308c\u3066\u3044\u307e\u3059\u3002\u30d1\u30f3\u30b0\u30e9\u30e0\u306f\u3001\u30d5\u30a9\u30f3\u30c8\u3001\u30ad\u30fc\u30dc\u30fc\u30c9\u3001\u304a\u3088\u3073\u305d\u306e\u4ed6\u306e\u30c6\u30ad\u30b9\u30c8\u95a2\u9023\u30c4\u30fc\u30eb\u3092\u30c6\u30b9\u30c8\u3059\u308b\u305f\u3081\u306b\u3088\u304f\u4f7f\u7528\u3055\u308c\u307e\u3059\u3002\u82f1\u8a9e\u4ee5\u5916\u306b\u3082\u3001\u591a\u304f\u306e\u4ed6\u306e\u8a00\u8a9e\u306e\u30d1\u30f3\u30b0\u30e9\u30e0\u304c\u3042\u308a\u307e\u3059\u3002\u8a00\u8a9e\u306e\u56fa\u6709\u306e\u7279\u6027\u306b\u3088\u3063\u3066\u3001\u3044\u304f\u3064\u304b\u306e\u30d1\u30f3\u30b0\u30e9\u30e0\u306f\u69cb\u7bc9\u3059\u308b\u306e\u304c\u96e3\u3057\u3044\u3082\u306e\u3082\u3042\u308a\u307e\u3059\u3002\n\u30c6\u30fc\u30d6\u30eb\u306e\u30c6\u30b9\u30c8', 'module': 'pdf_translator', 'name': 'translator.pdf_translator', 'process': (id=38860, name='MainProcess'), 'thread': (id=51360, name='MainThread'), 'time': datetime(2024, 7, 17, 11, 38, 45, 767131, tzinfo=datetime.timezone(datetime.timedelta(seconds=28800), 'China Standard Time'))}
# Traceback (most recent call last):
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_handler.py", line 206, in emit
#     self._sink.write(str_record)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_simple_sinks.py", line 16, in write
#     self._stream.write(message)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 130-135: character maps to <undefined>
# --- End of logging error ---
# --- Logging error in Loguru Handler #1 ---
# Record was: {'elapsed': datetime.timedelta(seconds=8, microseconds=141473), 'exception': None, 'extra': {}, 'file': (name='pdf_translator.py', path='D:\\Evan\\ITA\\Training\\open-AI\\HW\\openai-quickstart\\openai-translator\\ai_translator\\translator\\pdf_translator.py'), 'function': 'translate_pdf', 'level': (name='DEBUG', no=10, icon='\U0001f41e'), 'line': 19, 'message': '\u7ffb\u8bd1\u4e3a\u65e5\u6587\uff0c\u4ee5\u7a7a\u683c\u548c\u6362\u884c\u7b26\u8868\u793a\u8868\u683c\uff1a\n[Fruit, Color, Price (USD)] [Apple, Red, 1.20] [Banana, Yellow, 0.50] [Orange, Orange, 0.80] [Strawberry, Red, 2.50] [Blueberry, Blue, 3.00] [Kiwi, Green, 1.00] [Mango, Orange, 1.50] [Grape, Purple, 2.00]', 'module': 'pdf_translator', 'name': 'translator.pdf_translator', 'process': (id=38860, name='MainProcess'), 'thread': (id=51360, name='MainThread'), 'time': datetime(2024, 7, 17, 11, 38, 45, 769131, tzinfo=datetime.timezone(datetime.timedelta(seconds=28800), 'China Standard Time'))}
# Traceback (most recent call last):
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_handler.py", line 206, in emit
#     self._sink.write(str_record)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_simple_sinks.py", line 16, in write
#     self._stream.write(message)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 140-157: character maps to <undefined>
# --- End of logging error ---
# --- Logging error in Loguru Handler #1 ---
# Record was: {'elapsed': datetime.timedelta(seconds=10, microseconds=286884), 'exception': None, 'extra': {}, 'file': (name='pdf_translator.py', path='D:\\Evan\\ITA\\Training\\open-AI\\HW\\openai-quickstart\\openai-translator\\ai_translator\\translator\\pdf_translator.py'), 'function': 'translate_pdf', 'level': (name='INFO', no=20, icon='\u2139\ufe0f'), 'line': 21, 'message': '\u679c\u7269 \u8272 \u4fa1\u683c\uff08USD\uff09\n\u308a\u3093\u3054 \u8d64 1.20\n\u30d0\u30ca\u30ca \u9ec4\u8272 0.50\n\u30aa\u30ec\u30f3\u30b8 \u30aa\u30ec\u30f3\u30b8\u8272 0.80\n\u3044\u3061\u3054 \u8d64 2.50\n\u30d6\u30eb\u30fc\u30d9\u30ea\u30fc \u9752 3.00\n\u30ad\u30a6\u30a4 \u7dd1 1.00\n\u30de\u30f3\u30b4\u30fc \u30aa\u30ec\u30f3\u30b8\u8272 1.50\n\u3076\u3069\u3046 \u7d2b 2.00', 'module': 'pdf_translator', 'name': 'translator.pdf_translator', 'process': (id=38860, name='MainProcess'), 'thread': (id=51360, name='MainThread'), 'time': datetime(2024, 7, 17, 11, 38, 47, 914542, tzinfo=datetime.timezone(datetime.timedelta(seconds=28800), 'China Standard Time'))}
# Traceback (most recent call last):
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_handler.py", line 206, in emit
#     self._sink.write(str_record)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_simple_sinks.py", line 16, in write
#     self._stream.write(message)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 130-131: character maps to <undefined>
# --- End of logging error ---
# --- Logging error in Loguru Handler #1 ---
# Record was: {'elapsed': datetime.timedelta(seconds=10, microseconds=288883), 'exception': None, 'extra': {}, 'file': (name='content.py', path='D:\\Evan\\ITA\\Training\\open-AI\\HW\\openai-quickstart\\openai-translator\\ai_translator\\book\\content.py'), 'function': 'set_translation', 'level': (name='DEBUG', no=10, icon='\U0001f41e'), 'line': 49, 'message': '\u679c\u7269 \u8272 \u4fa1\u683c\uff08USD\uff09\n\u308a\u3093\u3054 \u8d64 1.20\n\u30d0\u30ca\u30ca \u9ec4\u8272 0.50\n\u30aa\u30ec\u30f3\u30b8 \u30aa\u30ec\u30f3\u30b8\u8272 0.80\n\u3044\u3061\u3054 \u8d64 2.50\n\u30d6\u30eb\u30fc\u30d9\u30ea\u30fc \u9752 3.00\n\u30ad\u30a6\u30a4 \u7dd1 1.00\n\u30de\u30f3\u30b4\u30fc \u30aa\u30ec\u30f3\u30b8\u8272 1.50\n\u3076\u3069\u3046 \u7d2b 2.00', 'module': 'content', 'name': 'book.content', 'process': (id=38860, name='MainProcess'), 'thread': (id=51360, name='MainThread'), 'time': datetime(2024, 7, 17, 11, 38, 47, 916541, tzinfo=datetime.timezone(datetime.timedelta(seconds=28800), 'China Standard Time'))}
# Traceback (most recent call last):
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_handler.py", line 206, in emit
#     self._sink.write(str_record)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_simple_sinks.py", line 16, in write
#     self._stream.write(message)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 129-130: character maps to <undefined>
# --- End of logging error ---
# --- Logging error in Loguru Handler #1 ---
# Record was: {'elapsed': datetime.timedelta(seconds=10, microseconds=289877), 'exception': None, 'extra': {}, 'file': (name='content.py', path='D:\\Evan\\ITA\\Training\\open-AI\\HW\\openai-quickstart\\openai-translator\\ai_translator\\book\\content.py'), 'function': 'set_translation', 'level': (name='DEBUG', no=10, icon='\U0001f41e'), 'line': 52, 'message': "[['\u679c\u7269', '\u8272', '\u4fa1\u683c\uff08USD\uff09'], ['\u308a\u3093\u3054', '\u8d64', '1.20'], ['\u30d0\u30ca\u30ca', '\u9ec4\u8272', '0.50'], ['\u30aa\u30ec\u30f3\u30b8', '\u30aa\u30ec\u30f3\u30b8\u8272', '0.80'], ['\u3044\u3061\u3054', '\u8d64', '2.50'], ['\u30d6\u30eb\u30fc\u30d9\u30ea\u30fc', '\u9752', '3.00'], ['\u30ad\u30a6\u30a4', '\u7dd1', '1.00'], ['\u30de\u30f3\u30b4\u30fc', '\u30aa\u30ec\u30f3\u30b8\u8272', '1.50'], ['\u3076\u3069\u3046', '\u7d2b', '2.00']]", 'module': 'content', 'name': 'book.content', 'process': (id=38860, name='MainProcess'), 'thread': (id=51360, name='MainThread'), 'time': datetime(2024, 7, 17, 11, 38, 47, 917535, tzinfo=datetime.timezone(datetime.timedelta(seconds=28800), 'China Standard Time'))}
# Traceback (most recent call last):
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_handler.py", line 206, in emit
#     self._sink.write(str_record)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_simple_sinks.py", line 16, in write
#     self._stream.write(message)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 132-133: character maps to <undefined>
# --- End of logging error ---
# --- Logging error in Loguru Handler #1 ---
# Record was: {'elapsed': datetime.timedelta(seconds=10, microseconds=291878), 'exception': None, 'extra': {}, 'file': (name='content.py', path='D:\\Evan\\ITA\\Training\\open-AI\\HW\\openai-quickstart\\openai-translator\\ai_translator\\book\\content.py'), 'function': 'set_translation', 'level': (name='DEBUG', no=10, icon='\U0001f41e'), 'line': 55, 'message': '       \u679c\u7269      \u8272 \u4fa1\u683c\uff08USD\uff09\n0     \u308a\u3093\u3054      \u8d64    1.20\n1     \u30d0\u30ca\u30ca     \u9ec4\u8272    0.50\n2    \u30aa\u30ec\u30f3\u30b8  \u30aa\u30ec\u30f3\u30b8\u8272    0.80\n3     \u3044\u3061\u3054      \u8d64    2.50\n4  \u30d6\u30eb\u30fc\u30d9\u30ea\u30fc      \u9752    3.00\n5     \u30ad\u30a6\u30a4      \u7dd1    1.00\n6    \u30de\u30f3\u30b4\u30fc  \u30aa\u30ec\u30f3\u30b8\u8272    1.50\n7     \u3076\u3069\u3046      \u7d2b    2.00', 'module': 'content', 'name': 'book.content', 'process': (id=38860, name='MainProcess'), 'thread': (id=51360, name='MainThread'), 'time': datetime(2024, 7, 17, 11, 38, 47, 919536, tzinfo=datetime.timezone(datetime.timedelta(seconds=28800), 'China Standard Time'))}
# Traceback (most recent call last):
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_handler.py", line 206, in emit
#     self._sink.write(str_record)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_simple_sinks.py", line 16, in write
#     self._stream.write(message)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 136-137: character maps to <undefined>
# --- End of logging error ---
# --- Logging error in Loguru Handler #1 ---
# Record was: {'elapsed': datetime.timedelta(seconds=10, microseconds=299404), 'exception': None, 'extra': {}, 'file': (name='writer.py', path='D:\\Evan\\ITA\\Training\\open-AI\\HW\\openai-quickstart\\openai-translator\\ai_translator\\translator\\writer.py'), 'function': '_save_translated_book_markdown', 'level': (name='INFO', no=20, icon='\u2139\ufe0f'), 'line': 84, 'message': '\u5f00\u59cb\u7ffb\u8bd1: tests/test_translated.md', 'module': 'writer', 'name': 'translator.writer', 'process': (id=38860, name='MainProcess'), 'thread': (id=51360, name='MainThread'), 'time': datetime(2024, 7, 17, 11, 38, 47, 927062, tzinfo=datetime.timezone(datetime.timedelta(seconds=28800), 'China Standard Time'))}
# Traceback (most recent call last):
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_handler.py", line 206, in emit
#     self._sink.write(str_record)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_simple_sinks.py", line 16, in write
#     self._stream.write(message)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 139-142: character maps to <undefined>
# --- End of logging error ---
# --- Logging error in Loguru Handler #1 ---
# Record was: {'elapsed': datetime.timedelta(seconds=10, microseconds=305410), 'exception': None, 'extra': {}, 'file': (name='writer.py', path='D:\\Evan\\ITA\\Training\\open-AI\\HW\\openai-quickstart\\openai-translator\\ai_translator\\translator\\writer.py'), 'function': '_save_translated_book_markdown', 'level': (name='INFO', no=20, icon='\u2139\ufe0f'), 'line': 108, 'message': '\u7ffb\u8bd1\u5b8c\u6210: tests/test_translated.md', 'module': 'writer', 'name': 'translator.writer', 'process': (id=38860, name='MainProcess'), 'thread': (id=51360, name='MainThread'), 'time': datetime(2024, 7, 17, 11, 38, 47, 933068, tzinfo=datetime.timezone(datetime.timedelta(seconds=28800), 'China Standard Time'))}
# Traceback (most recent call last):
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_handler.py", line 206, in emit
#     self._sink.write(str_record)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\site-packages\loguru\_simple_sinks.py", line 16, in write
#     self._stream.write(message)
#   File "C:\ProgramData\miniconda3\envs\langchain\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 140-143: character maps to <undefined>
# --- End of logging error ---
